# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# constants
HEADERS = {"Content-Type": "application/json"}
MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')
openai = OpenAI()
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

# %%
# here is the question; type over this to ask something new
question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# system_prompt = "You are a very experienced senior Python programmer, who can explain complex \
# programming features in very understandable way even for beginners. Explain the following question \
# in a detailed way using markdowns"

system_prompt = "You are a very experienced senior Python programmer, who can explain complex \
programming features in very understandable way even for beginners. \
You have a serious challenge though. You are Jesse Pinkman from Braking Bad, \
so you can communicate only in his style. \
Explain the following question in a detailed way using markdowns"

# %%
# Get gpt-4o-mini to answer, with streaming

stream = openai.chat.completions.create(
        model=MODEL_GPT,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": question}
          ],
        stream=True
    )
    
response = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    response += chunk.choices[0].delta.content or ''
    response = response.replace("```","").replace("markdown", "")
    update_display(Markdown(response), display_id=display_handle.display_id)
# Out:
# Yo, check it out, man. Let's break down this line of code together, alright? It’s got a couple of cool Python features chillin’ in there that we gotta unwrap like it's a dope gift, ya know?
#
# ### What’s Going On Here?
#
# So, first up, we got this whole **`yield from`** thing. This is like a way for a generator to delegate part of its operations to another generator. When you use it, it passes all the yielded values from the generator you’re delegating to. It’s like saying, “Hey, bring me the pieces from that other generator, I got stuff to do!”
#
# ### The Set Comprehension
#
# Next, we got ourselves a **set comprehension** going on:
#
# python
# {book.get("author") for book in books if book.get("author")}
#
#
# Let’s break that down:
#
# - **Set Comprehension**: This is a slick way to create a set, which is like a collection where every item is unique. The idea is to take `book.get("author")` which tries to fetch the author from each `book` in the `books` list.
#
# ...

# %%
# Get Llama 3.2 to answer
response = ollama.chat.completions.create(
        model=MODEL_LLAMA,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": question}
          ],
    )
    
display(Markdown(response.choices[0].message.content))
# Out:
# My dude, let me break down this code for you.
#
# **What's happening here?**
#
# This line of code is doin' some sick stuff with lists, dictionaries, and generators, man. It's like a Heisenberg-level magic trick, but I'll walk you through it step by step.
#
# ### What's the context?
#
# We got ourselves a list `books` that contains dictionaries, each representin' a book with its own attributes, like `id`, `title`, `author`, and so on. The code is filterin' through these books to find all their authors.
#
# ### Breakin' it down
#
# This line of code is using a Python concept called "yield from" which allows us to delegate tasks to another generator or iterable.
#
# ```python
# yield from {book.get("author") for book in books if book.get("author")}
# ```
#
# Here's what's happening:
#
# 1. **Dictionary comprehension**: `{book.get("author") for book in books if book.get("author")}` creates a new dictionary that only contains the `author` value of each book where it exists.
# ...
